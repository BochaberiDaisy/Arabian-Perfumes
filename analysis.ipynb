# %%
import pandas as pd

# %%
perfumes = pd.read_csv('perfumes.csv')

# %%
perfumes
# Out:
#                    name    price  brand  \
# 0              9AM DIVE  4,500/=  AFNAN
# 1                   9PM  4,500/=    NaN
# 2                 ADEEB  3,600/=    NaN
# 3        ADWAA AL SHARQ  2,300/=    NaN
# 4                 AFEEF  3,800/=    NaN
# ..                  ...      ...    ...
# 492                AURA  3,500/=    NaN
# 493      OUD WONDER EDP  1,900/=    NaN
# 494  ROYAL SAPPHIRE EDP  4,500/=    NaN
# 495   ROUAT AL MUSK EDP  2,100/=    NaN
# 496          OUDAIN EDP  2,000/=    NaN
#
#                                              top_notes  \
# 0    Top notes: Mint, Lemon, Pink Pepper and Black ...
# 1    Top notes: Apple, Cinnamon, Wild Lavender and ...
# 2    Top notes: Cinnamon, Vanilla, Tobacco.<br>\nMi...
# 3                                        Not Available
# 4                                        Not Available
# ..                                                 ...
# 492                                      Not Available
# ...
